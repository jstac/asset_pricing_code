# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from by_model import *

# %%
#by = BY(z_grid_size=10, σ_grid_size=10)

# %%
by=BY(read_from_file=True)

# %%
z, σ = by.simulate_state(ts_length=200)

# %%
plt.plot(z)

# %%
plt.plot(σ)

# %%
g_c, g_d, M = by.simulate_growth(ts_length=200, seed=12)

# %%
plt.plot(M[1:])

# %%
plt.plot(g_d)

# %%
plt.plot(np.cumprod(np.exp(g_d)))

# %%
by.test_ez_solution()
# Out:
# -9.255741133529227e-07

# %%
plt.plot(np.cumprod(M[1:400]))

# %%
g_c, g_d, M = by.simulate_growth(ts_length=100000)

# %%
np.std(g_d)
# Out:
# 0.03559678336286626

# %%
P, D, Z, Σ = by.compute_price_process(ts_length=100)

# %%
P
# Out:
# array([ 304.14847868,  315.34641806,  327.94404436,  342.12361806,
#         358.30420547,  377.79474226,  397.88734013,  418.33685569,
#         439.11770162,  460.20110709,  481.55592786,  503.1502827 ,
#         524.95040671,  546.92175437,  569.02882972,  591.23549704,
#         613.50547093,  635.80229878,  658.08919446,  680.33003268,
#         702.48889656,  724.53044979,  746.41971931,  768.12235105,
#         789.58960232,  810.79072572,  831.70487828,  852.30159963,
#         872.55163684,  892.42701696,  911.90090647,  930.94767195,
#         949.54329354,  967.66509405,  985.29178288, 1002.40358149,
#        1018.98206355, 1035.01022833, 1050.47273508, 1065.35565666,
#        1079.64652319, 1093.33429627, 1106.40929733, 1118.86343553,
#        1130.68982582, 1141.88286735, 1152.43843913, 1162.3535754 ,
#        1171.6265321 , 1180.25681714, 1188.24505786, 1195.59282831,
#        1202.30283832, 1208.37894011, 1213.82589335, 1218.64922209,
# ...

# %%
plt.plot(P)

# %%
plt.plot(Z)

# %%
plt.plot(Σ)

# %%
plt.plot()

# %%
p = np.log(P[1:] / P[:-1])
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plt.plot(p)

# %%
np.std(p)
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/numpy/core/_methods.py:112: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# nan

# %%
D = D[1:]
d = np.log(D[1:] / D[:-1])
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: overflow encountered in true_divide

# %%
plt.plot(d)

# %%
np.std(d)
# Out:
# 0.026751778689133632
