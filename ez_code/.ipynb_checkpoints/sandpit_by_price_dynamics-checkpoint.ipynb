# %%
include("stability_plots.jl")
# Out:
# stability_plot (generic function with 1 method)

# %%
@time stability_plot("by", :μ_c, 0.5, 0.2, :μ_d, 0.25, 6.0, G=20)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f14185d0dd8>)
# 535.134049 seconds (7.46 G allocations: 190.166 GiB, 3.27% gc time)

# %%
@time stability_plot("ssy", :ϕ_d, 0.2, 6.0, :μ_d, 0.25, 6.0, G=20, coords=(-5, 20))
# Out:
# 1191.
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f1414c31cf8>)
# 537581 seconds (34.78 G allocations: 622.501 GiB, 3.95% gc time)
