# %%
from by_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %%
by = BY()

# %%
compute_recursive_utility(by)
# Out:
# Converged in 3627 iterations

# %%
# %%time
sr = by.compute_spec_rad_of_V(n=5000)
sr()
# Out:
# CPU times: user 18.8 s, sys: 0 ns, total: 18.8 s
# Wall time: 3.07 s

# %%
sr = by.compute_suped_spec_rad()
sr()
# Out:
# 1.022458206846884

# %% [markdown]
# ## new

# %%
by.γ, by.β
# Out:
# (10.0, 0.998)

# %%
stability_plot(BY,
               'β', 0.9975, 0.999,
               'γ', 1.1, 14, 
                coords=(-225, -30), 
                G=12)
# Out:
# Converged in 3627 iterations
# Converged in 1657 iterations
# Converged in 1825 iterations
# Converged in 1734 iterations
# Converged in 1639 iterations
# Converged in 1547 iterations
# Converged in 1459 iterations
# Converged in 1378 iterations
# Converged in 1305 iterations
# Converged in 1240 iterations
# Converged in 1182 iterations
# Converged in 1130 iterations
# Converged in 1085 iterations
# Converged in 3190 iterations
# Converged in 1975 iterations
# Converged in 1896 iterations
# Converged in 1787 iterations
# Converged in 1682 iterations
# Converged in 1583 iterations
# Converged in 1492 iterations
# Converged in 1411 iterations
# Converged in 1339 iterations
# Converged in 1275 iterations
# Converged in 1218 iterations
# Converged in 1168 iterations
# Converged in 3490 iterations
# Converged in 2184 iterations
# Converged in 2085 iterations
# Converged in 1959 iterations
# Converged in 1838 iterations
# Converged in 1725 iterations
# Converged in 1624 iterations
# Converged in 1533 iterations
# Converged in 1452 iterations
# Converged in 1381 iterations
# Converged in 1319 iterations
# Converged in 1263 iterations
# Converged in 3846 iterations
# Converged in 2433 iterations
# Converged in 2309 iterations
# Converged in 2161 iterations
# Converged in 2020 iterations
# Converged in 1892 iterations
# Converged in 1776 iterations
# Converged in 1673 iterations
# Converged in 1583 iterations
# Converged in 1504 iterations
# Converged in 1434 iterations
# Converged in 1372 iterations
# Converged in 4276 iterations
# Converged in 2734 iterations
# Converged in 2578 iterations
# Converged in 2401 iterations
# Converged in 2236 iterations
# Converged in 2087 iterations
# Converged in 1954 iterations
# Converged in 1837 iterations
# Converged in 1735 iterations
# Converged in 1645 iterations
# Converged in 1566 iterations
# Converged in 1497 iterations
# Converged in 4804 iterations
# Converged in 3106 iterations
# Converged in 2905 iterations
# Converged in 2691 iterations
# Converged in 2495 iterations
# Converged in 2320 iterations
# Converged in 2166 iterations
# Converged in 2031 iterations
# Converged in 1914 iterations
# Converged in 1811 iterations
# Converged in 1722 iterations
# Converged in 1643 iterations
# Converged in 5467 iterations
# Converged in 3573 iterations
# Converged in 3312 iterations
# Converged in 3048 iterations
# Converged in 2810 iterations
# Converged in 2601 iterations
# Converged in 2420 iterations
# Converged in 2262 iterations
# Converged in 2126 iterations
# Converged in 2008 iterations
# Converged in 1905 iterations
# Converged in 1815 iterations
# Converged in 6322 iterations
# Converged in 4177 iterations
# Converged in 3830 iterations
# Converged in 3495 iterations
# Converged in 3202 iterations
# Converged in 2948 iterations
# Converged in 2730 iterations
# Converged in 2543 iterations
# Converged in 2383 iterations
# Converged in 2244 iterations
# Converged in 2125 iterations
# Converged in 2020 iterations
# Converged in 7466 iterations
# Converged in 4985 iterations
# Converged in 4508 iterations
# Converged in 4072 iterations
# Converged in 3699 iterations
# Converged in 3383 iterations
# Converged in 3116 iterations
# Converged in 2890 iterations
# Converged in 2697 iterations
# Converged in 2533 iterations
# Converged in 2391 iterations
# Converged in 2269 iterations
# Converged in 9070 iterations
# Converged in 6112 iterations
# Converged in 5430 iterations
# Converged in 4839 iterations
# Converged in 4349 iterations
# Converged in 3944 iterations
# Converged in 3608 iterations
# Converged in 3328 iterations
# Converged in 3092 iterations
# Converged in 2893 iterations
# Converged in 2722 iterations
# Converged in 2574 iterations
# Converged in 11477 iterations
# Converged in 7786 iterations
# Converged in 6747 iterations
# Converged in 5903 iterations
# Converged in 5231 iterations
# Converged in 4691 iterations
# Converged in 4254 iterations
# Converged in 3896 iterations
# Converged in 3599 iterations
# Converged in 3351 iterations
# Converged in 3140 iterations
# Converged in 2959 iterations
# Converged in 15472 iterations
# Converged in 10496 iterations
# Converged in 8767 iterations
# Converged in 7468 iterations
# Converged in 6487 iterations
# Converged in 5730 iterations
# Converged in 5135 iterations
# Converged in 4659 iterations
# Converged in 4272 iterations
# Converged in 3952 iterations
# Converged in 3683 iterations
# Converged in 3455 iterations

# %%
by.β, by.μ_d
# Out:
# (0.998, 0.0015)

# %%
stability_plot(BY, 
               'β', 0.995, 0.9985, 
               'μ_d', 0.0, 0.01, 
                ylabel="$\mu_d$",
                coords=(-100, 30), 
                G=12)
# Out:
# Converged in 3627 iterations
# Converged in 1507 iterations
# Converged in 918 iterations
# Converged in 1008 iterations
# Converged in 1107 iterations
# Converged in 1224 iterations
# Converged in 1365 iterations
# Converged in 1539 iterations
# Converged in 1758 iterations
# Converged in 2039 iterations
# Converged in 2415 iterations
# Converged in 2937 iterations
# Converged in 3711 iterations

# %%
by.α
# Out:
# 3.0

# %%
stability_plot(BY, 
               'α', 1.0, 5.0, 
               'μ_d', -0.002, 0.008, 
                ylabel="$\mu_d$",
                coords=(-100, 30), 
                G=10)
# Out:
# Converged in 3627 iterations

# %%
stability_plot(BY, 
               'α', -0.6, 4.0, 
               'μ_d', -0.02, 0.008, 
                ylabel="$\mu_d$",
                coords=(-100, 30), 
                one_step=True,
                G=10)
# Out:
# Converged in 3627 iterations

# %%
by.ϕ_d
# Out:
# 4.5

# %%
stability_plot(BY, 
               'α', 1.0, 5.0, 
               'ϕ_d', 0.0, 10.0, 
                ylabel="$\mu_d$",
                coords=(-100, 30), 
                G=3)
# Out:
# Converged in 3627 iterations

# %%
by.β, by.d
# Out:
# (0.998, 7.9092e-07)

# %%
by.β, by.ϕ_z
# Out:
# (0.998, 0.044)

# %%
stability_plot(BY,
               'β', 0.9975, 0.999, 
               'φ_z', 0.005, 0.06,
                coords=(-50, 30), 
                G=8)
# Out:
# Converged in 3627 iterations
# Converged in 2314 iterations
# Converged in 1626 iterations
# Converged in 1391 iterations
# Converged in 1184 iterations
# Converged in 1035 iterations
# Converged in 940 iterations
# Converged in 885 iterations
# Converged in 846 iterations
# Converged in 2708 iterations
# Converged in 1830 iterations
# Converged in 1583 iterations
# Converged in 1349 iterations
# Converged in 1181 iterations
# Converged in 1073 iterations
# Converged in 1011 iterations
# Converged in 967 iterations
# Converged in 3096 iterations
# Converged in 2118 iterations
# Converged in 1824 iterations
# Converged in 1555 iterations
# Converged in 1363 iterations
# Converged in 1240 iterations
# Converged in 1169 iterations
# Converged in 1117 iterations
# Converged in 3599 iterations
# Converged in 2490 iterations
# Converged in 2134 iterations
# Converged in 1820 iterations
# Converged in 1597 iterations
# Converged in 1454 iterations
# Converged in 1370 iterations
# Converged in 1309 iterations
# Converged in 4274 iterations
# Converged in 2989 iterations
# Converged in 2546 iterations
# Converged in 2171 iterations
# Converged in 1906 iterations
# Converged in 1736 iterations
# Converged in 1635 iterations
# Converged in 1561 iterations
# Converged in 5224 iterations
# Converged in 3688 iterations
# Converged in 3117 iterations
# Converged in 2653 iterations
# Converged in 2329 iterations
# Converged in 2122 iterations
# Converged in 1997 iterations
# Converged in 1905 iterations
# Converged in 6651 iterations
# Converged in 4729 iterations
# Converged in 3950 iterations
# Converged in 3351 iterations
# Converged in 2940 iterations
# Converged in 2676 iterations
# Converged in 2515 iterations
# Converged in 2395 iterations
# Converged in 9022 iterations
# Converged in 6425 iterations
# Converged in 5270 iterations
# Converged in 4441 iterations
# Converged in 3885 iterations
# Converged in 3528 iterations
# Converged in 3306 iterations
# Converged in 3139 iterations
# /home/john/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
