# %%
from by_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %%
by = BY()

# %%
compute_recursive_utility(by)
# Out:
# Converged in 3627 iterations

# %%
sr = by.compute_spec_rad_of_V()
sr()
# Out:
# 0.99631383131632

# %%
sr = by.compute_suped_spec_rad()
sr()
# Out:
# 1.022458206846884

# %% [markdown]
# ## new

# %%
by.γ, by.β
# Out:
# (10.0, 0.998)

# %%
stability_plot(BY,
               'β', 0.9975, 0.999,
               'γ', 1.1, 14, 
                coords=(-225, -30), 
                G=4)
# Out:
# Converged in 3615 iterations
# Converged in 2219 iterations
# Converged in 1880 iterations
# Converged in 1625 iterations
# Converged in 4297 iterations
# Converged in 3069 iterations
# Converged in 2517 iterations
# Converged in 2136 iterations
# Converged in 6882 iterations
# Converged in 4739 iterations
# Converged in 3669 iterations
# Converged in 3018 iterations
# Converged in 15765 iterations
# Converged in 9291 iterations
# Converged in 6294 iterations
# Converged in 4858 iterations

# %%
by.β, by.μ_d
# Out:
# (0.998, 0.0015)

# %%
stability_plot(BY, 
               'β', 0.995, 0.9985, 
               'μ_d', 0.0, 0.01, 
                ylabel="$\mu_d$",
                coords=(-100, 30), 
                G=4)
# Out:
# Converged in 1417 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 1475 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 2244 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 4343 iterations
# Converged in 2 iterations
# Converged in 2 iterations
# Converged in 2 iterations

# %%
by.β, by.d
# Out:
# (0.998, 7.9092e-07)

# %%
by.β, by.ϕ_z
# Out:
# (0.998, 0.044)

# %%
stability_plot(BY,
               'β', 0.995, 0.9985, 
               'φ_z', 0.005, 0.06,
                coords=(-50, 30), 
                G=4)
# Out:
# Converged in 1504 iterations
# Converged in 607 iterations
# Converged in 769 iterations
# Converged in 778 iterations
# Converged in 1687 iterations
# Converged in 908 iterations
# Converged in 1092 iterations
# Converged in 1078 iterations
# Converged in 2680 iterations
# Converged in 1560 iterations
# Converged in 1756 iterations
# Converged in 1661 iterations
# Converged in 5879 iterations
# Converged in 3754 iterations
# Converged in 3734 iterations
# Converged in 3210 iterations
