# %%
from ssy_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %% [markdown]
# #### Default instance with default parameter values

# %%
dssy = SSY()

# %%
# %%time
compute_recursive_utility(dssy)
# Out:
# Converged in 12271 iterations
# CPU times: user 14min 23s, sys: 10.5 s, total: 14min 33s
# Wall time: 1min 58s

# %%
sr = dssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9978480057837839

# %%
sr = dssy.compute_suped_spec_rad()
sr()
# Out:
# 1.0194006608328974

# %%
w_star = dssy.w_star_guess

# %% [markdown]
# #### Effect of changing $\mu_d$

# %%
dssy.μ_d
# Out:
# 0.001

# %%
ssy = SSY(μ_d=0.005)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0026311305536613

# %% [markdown]
# #### Effect of changing $\alpha$

# %%
dssy.α
# Out:
# 3.65

# %%
ssy = SSY(α=1.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0007887352646305

# %%
ssy = SSY(α=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9977842540992768

# %% [markdown]
# #### Effect of changing $\phi_d$

# %%
dssy.ϕ_d
# Out:
# 4.54

# %%
ssy = SSY(ϕ_d=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9990907178210968

# %% [markdown]
# #### Effect of changing $\delta$

# %%
dssy.δ
# Out:
# 1.47

# %%
ssy = SSY(δ=12.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0032149177638912

# %% [markdown]
# #### Effect of changing $\rho_h$

# %%
dssy.ρ_hd
# Out:
# 0.969

# %%
ssy = SSY(ρ_hd=0.99)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0343755921890618

# %% [markdown]
# ## new

# %%
stability_plot(SSY,
               'μ_d', 0.0, 0.004,
               'ϕ_d', 0.0, 12.0, 
                w_star_guess = w_star,
                coords=(225, -30), 
                G=8)

# %%
stability_plot(SSY,
               'μ_d', 0.0005, 0.003,
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=8)

# %%
stability_plot(SSY,
               'ϕ_d', 0.0, 12.0, 
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=8)

# %%
stability_plot(SSY,
               'μ_d', 0.0005, 0.003,
               'δ', 0.0, 10.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=4)

# %%
stability_plot(SSY,
               'α', 1.0, 6.0, 
               'δ', 0.0, 10.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=4)

# %%
stability_plot(SSY,
               'ρ_hd', 0.96, 0.985, 
                'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=4)
