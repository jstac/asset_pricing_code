# %%
from ssy_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %%
ssy = SSY()

# %%
compute_recursive_utility(ssy)
# Out:
# Converged in 12995 iterations

# %%
sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9985041973453346

# %%
sr = ssy.compute_suped_spec_rad()
sr()
# Out:
# 1.02152446858204

# %% [markdown]
# ## new

# %%
ssy.γ, ssy.β
# Out:
# (8.89, 0.999)

# %%
stability_plot(SSY,
               'β', 0.9985, 0.9992,
               'γ', 1.1, 14, 
                coords=(-225, -30), 
                G=3)
# Out:
# Converged in 8169 iterations
# Converged in 5060 iterations
# Converged in 5117 iterations
# ------------------------------------------------------------------
# KeyboardInterrupt                Traceback (most recent call last)
# <ipython-input-8-cdfaaebc6ad5> in <module>()
#       3                'γ', 1.1, 14,
#       4                 coords=(-225, -30),
# ----> 5                 G=3)
#
# ~/sync_dir/papers/fwd_looking_eqs/code/ez_code/stability_plots.py in stability_plot(ModelClass, param1, p1_min, p1_max, param2, p2_min, p2_max, xlabel, ylabel, coords, G, one_step)
#      49             md.build_grid_and_shocks()
#      50
# ---> 51             compute_recursive_utility(md)
#      52             if one_step:
#      53                 sr = md.compute_suped_spec_rad(n=1, num_reps=8000)
#
# ~/sync_dir/papers/fwd_looking_eqs/code/ez_code/utility_solver.py in compute_recursive_utility(model, tol, max_iter, verbose)
#      16
#      17     while error > tol and i < max_iter:
# ---> 18         w_out = T(w_in)
#      19         error = np.max(np.abs(w_in - w_out))
#      20         i += 1
#
# KeyboardInterrupt:
