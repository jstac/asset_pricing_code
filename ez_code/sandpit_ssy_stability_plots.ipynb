# %%
from ssy_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %% [markdown]
# #### Default instance with default parameter values

# %%
dssy = SSY()

# %%
# %%time
compute_recursive_utility(dssy)
# Out:
# Converged in 13381 iterations
# CPU times: user 15min 39s, sys: 12.1 s, total: 15min 51s
# Wall time: 2min 8s

# %%
sr = dssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9986286163964452

# %%
sr = dssy.compute_suped_spec_rad()
sr()
# Out:
# 1.0231009635779094

# %%
w_star = dssy.w_star_guess

# %% [markdown]
# #### Effect of changing $\mu_d$

# %%
dssy.μ_d
# Out:
# 0.001

# %%
ssy = SSY(μ_d=0.005)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0026311305536613

# %% [markdown]
# #### Effect of changing $\alpha$

# %%
dssy.α
# Out:
# 3.65

# %%
ssy = SSY(α=1.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0007887352646305

# %%
ssy = SSY(α=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9977842540992768

# %% [markdown]
# #### Effect of changing $\phi_d$

# %%
dssy.ϕ_d
# Out:
# 4.54

# %%
ssy = SSY(ϕ_d=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9990907178210968

# %% [markdown]
# ## new

# %%
stability_plot(SSY,
               'μ_d', 0.0, 0.004,
               'ϕ_d', 0.0, 12.0, 
                w_star_guess = w_star,
                coords=(225, -30), 
                G=8)

# %%
stability_plot(SSY,
               'μ_d', 0.0005, 0.003,
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=8)

# %%
stability_plot(SSY,
               'ϕ_d', 0.0, 12.0, 
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(225, -30), 
                G=8)
