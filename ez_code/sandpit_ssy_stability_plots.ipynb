# %%
from ssy_model import *
from utility_solver import compute_recursive_utility

# %%
from stability_plots import stability_plot

# %% [markdown]
# #### Default instance with default parameter values

# %%
dssy = SSY()

# %%
# %%time
compute_recursive_utility(dssy)
# Out:
# Converged in 12636 iterations
# CPU times: user 1h 14min 19s, sys: 5.3 s, total: 1h 14min 24s
# Wall time: 32min 54s

# %%
sr = dssy.compute_spec_rad_of_V(n=1000)
sr()
# Out:
# 0.996944621658555

# %%
sr = dssy.compute_suped_spec_rad()
sr()
# Out:
# 1.0129577688232665

# %%
w_star = dssy.w_star_guess

# %% [markdown]
# #### Effect of changing $\mu_d$

# %%
dssy.μ_d
# Out:
# 0.001

# %%
ssy = SSY(μ_d=0.005)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.001628691032989

# %% [markdown]
# #### Effect of changing $\alpha$

# %%
dssy.α
# Out:
# 3.65

# %%
ssy = SSY(α=1.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9999204681265204

# %%
ssy = SSY(α=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9958582042936686

# %% [markdown]
# #### Effect of changing $\phi_d$

# %%
dssy.ϕ_d
# Out:
# 4.54

# %%
ssy = SSY(ϕ_d=8.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.9999582830536486

# %% [markdown]
# #### Effect of changing $\delta$

# %%
dssy.δ
# Out:
# 1.47

# %%
ssy = SSY(δ=12.0)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 0.996201584935667

# %% [markdown]
# #### Effect of changing $\rho_h$

# %%
dssy.ρ_hd
# Out:
# 0.969

# %%
ssy = SSY(ρ_hd=0.99)
ssy.w_star_guess = w_star

sr = ssy.compute_spec_rad_of_V()
sr()
# Out:
# 1.0878089836152034

# %% [markdown]
# ## new

# %%
stability_plot(SSY,
               'ϕ_d', 0.0, 10.0, 
                'μ_d', 0.0, 0.006,
                ylabel="$\mu_d$",
                xlabel="$\phi_d$",
                w_star_guess = w_star,
                coords=(-60, 40), 
                G=12)

# %%
stability_plot(SSY,
               'ϕ_d', -2.0, 8.0, 
                'μ_d', -0.0068, 0.004,
                ylabel="$\mu_d$",
                xlabel="$\phi_d$",
                w_star_guess = w_star,
                coords=(-60, 40), 
                one_step=True,
                G=3)
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
stability_plot(SSY,
               'μ_d', 0.0005, 0.003,
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(60, 30), 
                G=8)

# %%
stability_plot(SSY,
               'ϕ_d', 0.0, 12.0, 
               'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(-30, 50), 
                G=8)

# %%
stability_plot(SSY,
               'μ_d', 0.0005, 0.003,
               'δ', 0.0, 10.0, 
                w_star_guess=w_star, 
                coords=(45, -30), 
                G=12)
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
stability_plot(SSY,
               'α', 1.0, 6.0, 
               'δ', 0.0, 10.0, 
                w_star_guess=w_star, 
                coords=(-25, 50), 
                G=12)
# Out:
# /home/john/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:1180: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"

# %%
stability_plot(SSY,
               'ρ_hd', 0.96, 0.985, 
                'α', 1.0, 6.0, 
                w_star_guess=w_star, 
                coords=(-55, 55), 
                G=12)
